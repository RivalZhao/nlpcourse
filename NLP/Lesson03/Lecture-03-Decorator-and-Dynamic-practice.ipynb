# %%
from collections import defaultdict

# %%
from functools import wraps

import time

# %% [markdown]
# ## Get the max splitting by enumerate

# %%
max(1, 2, 3, 4)
# Out:
# 4

# %%
def example(f, arg):
    return f(arg)
def add_ten(num):
    return num + 10
def mul_ten(num):
    return num * 10

# %%
operations = [add_ten, mul_ten]

for f in operations:
    print(example(f, 100))
# Out:
# 110
# 1000

# %%
called_time = defaultdict(int)

def get_call_times(f):
    start = time.time()
    f()
    print('function: {} called once! used time: {}'.format(f.__name__, time.time() - start))
    called_time[f.__name__] += 1
    print('times:' + str(called_time[f.__name__]))
    #return result

def some_funcion_1(): print('I am function 1')

# %%
get_call_times(some_funcion_1)
# Out:
# I am function 1
# function: some_funcion_1 called once! used time: 0.0
# times:2

# %%
called_time
# Out:
# defaultdict(int, {'some_funcion_1': 2})

# %%
call_time_with_arg = defaultdict(int)

# %%
#del call_time_with_arg

# %%
called_time_with_arg = defaultdict(int)

def get_call_time(f):
    """@param f is a function"""
    @wraps(f)
    def wrap(n):
        """Haha I am warp"""
        start = time.time()
        #print('I can count')
        result = f(n)
        called_time_with_arg[(f.__name__, n)] += 1
        print('this is ' + str(called_time_with_arg) )
        print('function: {} called once! used time: {}'.format(f.__name__, time.time() - start))
        return result
    return wrap

# %%
def add_ten(n): return n + 10

# %%
add_ten(10)
# Out:
# 20

# %%
add_ten = get_call_time(add_ten)

# %%
add_ten(20)
# Out:
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1})
# function: add_ten called once! used time: 0.0
# 30

# %%
@get_call_time
def add_twenty(n): 
    return n + 20

# %%
add_twenty(9)
# Out:
# I can count
# this is defaultdict(<class 'int'>, {('add_ten', 20): 2, ('add_twenty', 9): 4})
# 29

# %% [markdown]
# ## Dynamic Programming

# %% [markdown]
# + 1. Overlapping Subproblems
# + 2. Overlapping computing saved in a table
# + 3. Parse solution

# %%
original_price = [1, 5, 8, 9, 10, 17, 17, 20, 24, 30, 31]
price = defaultdict(int)
for i, p in enumerate(original_price): 
    price[i + 1] = p
price[1]
# Out:
# 1

# %%
def r(n):
    #fname = r.__name__
    #call_time_with_arg[(fname, n)] += 1
    return max(
        [price[n]] + [r(i) + r(n-i) for i in range(1, n)]
    )

# %%
r(15)
# Out:
# 45

# %%
def memo(f): 
    memo.already_computed = {}
    @wraps(f)
    def _wrap(arg):
        result = None
        
        if arg in memo.already_computed: 
            result = memo.already_computed[arg]
        else:
            result = f(arg)
            memo.already_computed[arg] = result
        
        return result
    
    return _wrap

# %%
solution = {}

# %%
@get_call_time
@memo
def r(n):
    """
    Args: n is the iron length
    Return: the max revenue 
    """
    max_price, max_split = max(
        [(price[n], 0)] + [(r(i) + r(n-i), i) for i in range(1, n)], key=lambda x: x[0]
    )

    solution[n] = (n - max_split, max_split)
    
    return max_price

# %%
r(22)
# Out:
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 3})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 4})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 5})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 6})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 7})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 8})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 9})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 10})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 11})
# function: r called once! used time: 0.0009908676147460938
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 12})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 13})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 14})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 15})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 16})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 17})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 18})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 19})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 20})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 21})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 22})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 22, ('r', 2): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 22, ('r', 2): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 23, ('r', 2): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 23, ('r', 2): 2, ('r', 3): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 23, ('r', 2): 3, ('r', 3): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 23, ('r', 2): 4, ('r', 3): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 23, ('r', 2): 4, ('r', 3): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 24, ('r', 2): 4, ('r', 3): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 24, ('r', 2): 4, ('r', 3): 2, ('r', 4): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 24, ('r', 2): 5, ('r', 3): 2, ('r', 4): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 24, ('r', 2): 5, ('r', 3): 3, ('r', 4): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 24, ('r', 2): 5, ('r', 3): 4, ('r', 4): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 24, ('r', 2): 6, ('r', 3): 4, ('r', 4): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 24, ('r', 2): 6, ('r', 3): 4, ('r', 4): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 25, ('r', 2): 6, ('r', 3): 4, ('r', 4): 2})
# function: r called once! used time: 0.001001596450805664
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 25, ('r', 2): 6, ('r', 3): 4, ('r', 4): 2, ('r', 5): 1})
# function: r called once! used time: 0.001001596450805664
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 25, ('r', 2): 7, ('r', 3): 4, ('r', 4): 2, ('r', 5): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 25, ('r', 2): 7, ('r', 3): 4, ('r', 4): 3, ('r', 5): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 25, ('r', 2): 7, ('r', 3): 5, ('r', 4): 3, ('r', 5): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 25, ('r', 2): 7, ('r', 3): 6, ('r', 4): 3, ('r', 5): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 25, ('r', 2): 7, ('r', 3): 6, ('r', 4): 4, ('r', 5): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 25, ('r', 2): 8, ('r', 3): 6, ('r', 4): 4, ('r', 5): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 25, ('r', 2): 8, ('r', 3): 6, ('r', 4): 4, ('r', 5): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 26, ('r', 2): 8, ('r', 3): 6, ('r', 4): 4, ('r', 5): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 26, ('r', 2): 8, ('r', 3): 6, ('r', 4): 4, ('r', 5): 2, ('r', 6): 1})
# function: r called once! used time: 0.001001596450805664
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 26, ('r', 2): 9, ('r', 3): 6, ('r', 4): 4, ('r', 5): 2, ('r', 6): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 26, ('r', 2): 9, ('r', 3): 6, ('r', 4): 4, ('r', 5): 3, ('r', 6): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 26, ('r', 2): 9, ('r', 3): 7, ('r', 4): 4, ('r', 5): 3, ('r', 6): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 26, ('r', 2): 9, ('r', 3): 7, ('r', 4): 5, ('r', 5): 3, ('r', 6): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 26, ('r', 2): 9, ('r', 3): 7, ('r', 4): 6, ('r', 5): 3, ('r', 6): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 26, ('r', 2): 9, ('r', 3): 8, ('r', 4): 6, ('r', 5): 3, ('r', 6): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 26, ('r', 2): 9, ('r', 3): 8, ('r', 4): 6, ('r', 5): 4, ('r', 6): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 26, ('r', 2): 10, ('r', 3): 8, ('r', 4): 6, ('r', 5): 4, ('r', 6): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 26, ('r', 2): 10, ('r', 3): 8, ('r', 4): 6, ('r', 5): 4, ('r', 6): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 27, ('r', 2): 10, ('r', 3): 8, ('r', 4): 6, ('r', 5): 4, ('r', 6): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 27, ('r', 2): 10, ('r', 3): 8, ('r', 4): 6, ('r', 5): 4, ('r', 6): 2, ('r', 7): 1})
# function: r called once! used time: 0.001001596450805664
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 27, ('r', 2): 11, ('r', 3): 8, ('r', 4): 6, ('r', 5): 4, ('r', 6): 2, ('r', 7): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 27, ('r', 2): 11, ('r', 3): 8, ('r', 4): 6, ('r', 5): 4, ('r', 6): 3, ('r', 7): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 27, ('r', 2): 11, ('r', 3): 9, ('r', 4): 6, ('r', 5): 4, ('r', 6): 3, ('r', 7): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 27, ('r', 2): 11, ('r', 3): 9, ('r', 4): 6, ('r', 5): 5, ('r', 6): 3, ('r', 7): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 27, ('r', 2): 11, ('r', 3): 9, ('r', 4): 7, ('r', 5): 5, ('r', 6): 3, ('r', 7): 1})
# function: r called once! used time: 0.0009999275207519531
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 27, ('r', 2): 11, ('r', 3): 9, ('r', 4): 8, ('r', 5): 5, ('r', 6): 3, ('r', 7): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 27, ('r', 2): 11, ('r', 3): 9, ('r', 4): 8, ('r', 5): 6, ('r', 6): 3, ('r', 7): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 27, ('r', 2): 11, ('r', 3): 10, ('r', 4): 8, ('r', 5): 6, ('r', 6): 3, ('r', 7): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 27, ('r', 2): 11, ('r', 3): 10, ('r', 4): 8, ('r', 5): 6, ('r', 6): 4, ('r', 7): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 27, ('r', 2): 12, ('r', 3): 10, ('r', 4): 8, ('r', 5): 6, ('r', 6): 4, ('r', 7): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 27, ('r', 2): 12, ('r', 3): 10, ('r', 4): 8, ('r', 5): 6, ('r', 6): 4, ('r', 7): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 28, ('r', 2): 12, ('r', 3): 10, ('r', 4): 8, ('r', 5): 6, ('r', 6): 4, ('r', 7): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 28, ('r', 2): 12, ('r', 3): 10, ('r', 4): 8, ('r', 5): 6, ('r', 6): 4, ('r', 7): 2, ('r', 8): 1})
# function: r called once! used time: 0.002001523971557617
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 28, ('r', 2): 13, ('r', 3): 10, ('r', 4): 8, ('r', 5): 6, ('r', 6): 4, ('r', 7): 2, ('r', 8): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 28, ('r', 2): 13, ('r', 3): 10, ('r', 4): 8, ('r', 5): 6, ('r', 6): 4, ('r', 7): 3, ('r', 8): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 28, ('r', 2): 13, ('r', 3): 11, ('r', 4): 8, ('r', 5): 6, ('r', 6): 4, ('r', 7): 3, ('r', 8): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 28, ('r', 2): 13, ('r', 3): 11, ('r', 4): 8, ('r', 5): 6, ('r', 6): 5, ('r', 7): 3, ('r', 8): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 28, ('r', 2): 13, ('r', 3): 11, ('r', 4): 9, ('r', 5): 6, ('r', 6): 5, ('r', 7): 3, ('r', 8): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 28, ('r', 2): 13, ('r', 3): 11, ('r', 4): 9, ('r', 5): 7, ('r', 6): 5, ('r', 7): 3, ('r', 8): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 28, ('r', 2): 13, ('r', 3): 11, ('r', 4): 9, ('r', 5): 8, ('r', 6): 5, ('r', 7): 3, ('r', 8): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 28, ('r', 2): 13, ('r', 3): 11, ('r', 4): 10, ('r', 5): 8, ('r', 6): 5, ('r', 7): 3, ('r', 8): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 28, ('r', 2): 13, ('r', 3): 11, ('r', 4): 10, ('r', 5): 8, ('r', 6): 6, ('r', 7): 3, ('r', 8): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 28, ('r', 2): 13, ('r', 3): 12, ('r', 4): 10, ('r', 5): 8, ('r', 6): 6, ('r', 7): 3, ('r', 8): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 28, ('r', 2): 13, ('r', 3): 12, ('r', 4): 10, ('r', 5): 8, ('r', 6): 6, ('r', 7): 4, ('r', 8): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 28, ('r', 2): 14, ('r', 3): 12, ('r', 4): 10, ('r', 5): 8, ('r', 6): 6, ('r', 7): 4, ('r', 8): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 28, ('r', 2): 14, ('r', 3): 12, ('r', 4): 10, ('r', 5): 8, ('r', 6): 6, ('r', 7): 4, ('r', 8): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 29, ('r', 2): 14, ('r', 3): 12, ('r', 4): 10, ('r', 5): 8, ('r', 6): 6, ('r', 7): 4, ('r', 8): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 29, ('r', 2): 14, ('r', 3): 12, ('r', 4): 10, ('r', 5): 8, ('r', 6): 6, ('r', 7): 4, ('r', 8): 2, ('r', 9): 1})
# function: r called once! used time: 0.002001523971557617
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 29, ('r', 2): 15, ('r', 3): 12, ('r', 4): 10, ('r', 5): 8, ('r', 6): 6, ('r', 7): 4, ('r', 8): 2, ('r', 9): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 29, ('r', 2): 15, ('r', 3): 12, ('r', 4): 10, ('r', 5): 8, ('r', 6): 6, ('r', 7): 4, ('r', 8): 3, ('r', 9): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 29, ('r', 2): 15, ('r', 3): 13, ('r', 4): 10, ('r', 5): 8, ('r', 6): 6, ('r', 7): 4, ('r', 8): 3, ('r', 9): 1})
# function: r called once! used time: 0.0010020732879638672
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 29, ('r', 2): 15, ('r', 3): 13, ('r', 4): 10, ('r', 5): 8, ('r', 6): 6, ('r', 7): 5, ('r', 8): 3, ('r', 9): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 29, ('r', 2): 15, ('r', 3): 13, ('r', 4): 11, ('r', 5): 8, ('r', 6): 6, ('r', 7): 5, ('r', 8): 3, ('r', 9): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 29, ('r', 2): 15, ('r', 3): 13, ('r', 4): 11, ('r', 5): 8, ('r', 6): 7, ('r', 7): 5, ('r', 8): 3, ('r', 9): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 29, ('r', 2): 15, ('r', 3): 13, ('r', 4): 11, ('r', 5): 9, ('r', 6): 7, ('r', 7): 5, ('r', 8): 3, ('r', 9): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 29, ('r', 2): 15, ('r', 3): 13, ('r', 4): 11, ('r', 5): 10, ('r', 6): 7, ('r', 7): 5, ('r', 8): 3, ('r', 9): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 29, ('r', 2): 15, ('r', 3): 13, ('r', 4): 11, ('r', 5): 10, ('r', 6): 8, ('r', 7): 5, ('r', 8): 3, ('r', 9): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 29, ('r', 2): 15, ('r', 3): 13, ('r', 4): 12, ('r', 5): 10, ('r', 6): 8, ('r', 7): 5, ('r', 8): 3, ('r', 9): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 29, ('r', 2): 15, ('r', 3): 13, ('r', 4): 12, ('r', 5): 10, ('r', 6): 8, ('r', 7): 6, ('r', 8): 3, ('r', 9): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 29, ('r', 2): 15, ('r', 3): 14, ('r', 4): 12, ('r', 5): 10, ('r', 6): 8, ('r', 7): 6, ('r', 8): 3, ('r', 9): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 29, ('r', 2): 15, ('r', 3): 14, ('r', 4): 12, ('r', 5): 10, ('r', 6): 8, ('r', 7): 6, ('r', 8): 4, ('r', 9): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 29, ('r', 2): 16, ('r', 3): 14, ('r', 4): 12, ('r', 5): 10, ('r', 6): 8, ('r', 7): 6, ('r', 8): 4, ('r', 9): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 29, ('r', 2): 16, ('r', 3): 14, ('r', 4): 12, ('r', 5): 10, ('r', 6): 8, ('r', 7): 6, ('r', 8): 4, ('r', 9): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 30, ('r', 2): 16, ('r', 3): 14, ('r', 4): 12, ('r', 5): 10, ('r', 6): 8, ('r', 7): 6, ('r', 8): 4, ('r', 9): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 30, ('r', 2): 16, ('r', 3): 14, ('r', 4): 12, ('r', 5): 10, ('r', 6): 8, ('r', 7): 6, ('r', 8): 4, ('r', 9): 2, ('r', 10): 1})
# function: r called once! used time: 0.0030035972595214844
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 30, ('r', 2): 17, ('r', 3): 14, ('r', 4): 12, ('r', 5): 10, ('r', 6): 8, ('r', 7): 6, ('r', 8): 4, ('r', 9): 2, ('r', 10): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 30, ('r', 2): 17, ('r', 3): 14, ('r', 4): 12, ('r', 5): 10, ('r', 6): 8, ('r', 7): 6, ('r', 8): 4, ('r', 9): 3, ('r', 10): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 30, ('r', 2): 17, ('r', 3): 15, ('r', 4): 12, ('r', 5): 10, ('r', 6): 8, ('r', 7): 6, ('r', 8): 4, ('r', 9): 3, ('r', 10): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 30, ('r', 2): 17, ('r', 3): 15, ('r', 4): 12, ('r', 5): 10, ('r', 6): 8, ('r', 7): 6, ('r', 8): 5, ('r', 9): 3, ('r', 10): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 30, ('r', 2): 17, ('r', 3): 15, ('r', 4): 13, ('r', 5): 10, ('r', 6): 8, ('r', 7): 6, ('r', 8): 5, ('r', 9): 3, ('r', 10): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 30, ('r', 2): 17, ('r', 3): 15, ('r', 4): 13, ('r', 5): 10, ('r', 6): 8, ('r', 7): 7, ('r', 8): 5, ('r', 9): 3, ('r', 10): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 30, ('r', 2): 17, ('r', 3): 15, ('r', 4): 13, ('r', 5): 11, ('r', 6): 8, ('r', 7): 7, ('r', 8): 5, ('r', 9): 3, ('r', 10): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 30, ('r', 2): 17, ('r', 3): 15, ('r', 4): 13, ('r', 5): 11, ('r', 6): 9, ('r', 7): 7, ('r', 8): 5, ('r', 9): 3, ('r', 10): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 30, ('r', 2): 17, ('r', 3): 15, ('r', 4): 13, ('r', 5): 11, ('r', 6): 10, ('r', 7): 7, ('r', 8): 5, ('r', 9): 3, ('r', 10): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 30, ('r', 2): 17, ('r', 3): 15, ('r', 4): 13, ('r', 5): 12, ('r', 6): 10, ('r', 7): 7, ('r', 8): 5, ('r', 9): 3, ('r', 10): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 30, ('r', 2): 17, ('r', 3): 15, ('r', 4): 13, ('r', 5): 12, ('r', 6): 10, ('r', 7): 8, ('r', 8): 5, ('r', 9): 3, ('r', 10): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 30, ('r', 2): 17, ('r', 3): 15, ('r', 4): 14, ('r', 5): 12, ('r', 6): 10, ('r', 7): 8, ('r', 8): 5, ('r', 9): 3, ('r', 10): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 30, ('r', 2): 17, ('r', 3): 15, ('r', 4): 14, ('r', 5): 12, ('r', 6): 10, ('r', 7): 8, ('r', 8): 6, ('r', 9): 3, ('r', 10): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 30, ('r', 2): 17, ('r', 3): 16, ('r', 4): 14, ('r', 5): 12, ('r', 6): 10, ('r', 7): 8, ('r', 8): 6, ('r', 9): 3, ('r', 10): 1})
# function: r called once! used time: 0.0010094642639160156
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 30, ('r', 2): 17, ('r', 3): 16, ('r', 4): 14, ('r', 5): 12, ('r', 6): 10, ('r', 7): 8, ('r', 8): 6, ('r', 9): 4, ('r', 10): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 30, ('r', 2): 18, ('r', 3): 16, ('r', 4): 14, ('r', 5): 12, ('r', 6): 10, ('r', 7): 8, ('r', 8): 6, ('r', 9): 4, ('r', 10): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 30, ('r', 2): 18, ('r', 3): 16, ('r', 4): 14, ('r', 5): 12, ('r', 6): 10, ('r', 7): 8, ('r', 8): 6, ('r', 9): 4, ('r', 10): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 18, ('r', 3): 16, ('r', 4): 14, ('r', 5): 12, ('r', 6): 10, ('r', 7): 8, ('r', 8): 6, ('r', 9): 4, ('r', 10): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 18, ('r', 3): 16, ('r', 4): 14, ('r', 5): 12, ('r', 6): 10, ('r', 7): 8, ('r', 8): 6, ('r', 9): 4, ('r', 10): 2, ('r', 11): 1})
# function: r called once! used time: 0.0040130615234375
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 19, ('r', 3): 16, ('r', 4): 14, ('r', 5): 12, ('r', 6): 10, ('r', 7): 8, ('r', 8): 6, ('r', 9): 4, ('r', 10): 2, ('r', 11): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 19, ('r', 3): 16, ('r', 4): 14, ('r', 5): 12, ('r', 6): 10, ('r', 7): 8, ('r', 8): 6, ('r', 9): 4, ('r', 10): 3, ('r', 11): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 19, ('r', 3): 17, ('r', 4): 14, ('r', 5): 12, ('r', 6): 10, ('r', 7): 8, ('r', 8): 6, ('r', 9): 4, ('r', 10): 3, ('r', 11): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 19, ('r', 3): 17, ('r', 4): 14, ('r', 5): 12, ('r', 6): 10, ('r', 7): 8, ('r', 8): 6, ('r', 9): 5, ('r', 10): 3, ('r', 11): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 19, ('r', 3): 17, ('r', 4): 15, ('r', 5): 12, ('r', 6): 10, ('r', 7): 8, ('r', 8): 6, ('r', 9): 5, ('r', 10): 3, ('r', 11): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 19, ('r', 3): 17, ('r', 4): 15, ('r', 5): 12, ('r', 6): 10, ('r', 7): 8, ('r', 8): 7, ('r', 9): 5, ('r', 10): 3, ('r', 11): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 19, ('r', 3): 17, ('r', 4): 15, ('r', 5): 13, ('r', 6): 10, ('r', 7): 8, ('r', 8): 7, ('r', 9): 5, ('r', 10): 3, ('r', 11): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 19, ('r', 3): 17, ('r', 4): 15, ('r', 5): 13, ('r', 6): 10, ('r', 7): 9, ('r', 8): 7, ('r', 9): 5, ('r', 10): 3, ('r', 11): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 19, ('r', 3): 17, ('r', 4): 15, ('r', 5): 13, ('r', 6): 11, ('r', 7): 9, ('r', 8): 7, ('r', 9): 5, ('r', 10): 3, ('r', 11): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 19, ('r', 3): 17, ('r', 4): 15, ('r', 5): 13, ('r', 6): 12, ('r', 7): 9, ('r', 8): 7, ('r', 9): 5, ('r', 10): 3, ('r', 11): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 19, ('r', 3): 17, ('r', 4): 15, ('r', 5): 13, ('r', 6): 12, ('r', 7): 10, ('r', 8): 7, ('r', 9): 5, ('r', 10): 3, ('r', 11): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 19, ('r', 3): 17, ('r', 4): 15, ('r', 5): 14, ('r', 6): 12, ('r', 7): 10, ('r', 8): 7, ('r', 9): 5, ('r', 10): 3, ('r', 11): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 19, ('r', 3): 17, ('r', 4): 15, ('r', 5): 14, ('r', 6): 12, ('r', 7): 10, ('r', 8): 8, ('r', 9): 5, ('r', 10): 3, ('r', 11): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 19, ('r', 3): 17, ('r', 4): 16, ('r', 5): 14, ('r', 6): 12, ('r', 7): 10, ('r', 8): 8, ('r', 9): 5, ('r', 10): 3, ('r', 11): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 19, ('r', 3): 17, ('r', 4): 16, ('r', 5): 14, ('r', 6): 12, ('r', 7): 10, ('r', 8): 8, ('r', 9): 6, ('r', 10): 3, ('r', 11): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 19, ('r', 3): 18, ('r', 4): 16, ('r', 5): 14, ('r', 6): 12, ('r', 7): 10, ('r', 8): 8, ('r', 9): 6, ('r', 10): 3, ('r', 11): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 19, ('r', 3): 18, ('r', 4): 16, ('r', 5): 14, ('r', 6): 12, ('r', 7): 10, ('r', 8): 8, ('r', 9): 6, ('r', 10): 4, ('r', 11): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 20, ('r', 3): 18, ('r', 4): 16, ('r', 5): 14, ('r', 6): 12, ('r', 7): 10, ('r', 8): 8, ('r', 9): 6, ('r', 10): 4, ('r', 11): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 31, ('r', 2): 20, ('r', 3): 18, ('r', 4): 16, ('r', 5): 14, ('r', 6): 12, ('r', 7): 10, ('r', 8): 8, ('r', 9): 6, ('r', 10): 4, ('r', 11): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 20, ('r', 3): 18, ('r', 4): 16, ('r', 5): 14, ('r', 6): 12, ('r', 7): 10, ('r', 8): 8, ('r', 9): 6, ('r', 10): 4, ('r', 11): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 20, ('r', 3): 18, ('r', 4): 16, ('r', 5): 14, ('r', 6): 12, ('r', 7): 10, ('r', 8): 8, ('r', 9): 6, ('r', 10): 4, ('r', 11): 2, ('r', 12): 1})
# function: r called once! used time: 0.005003929138183594
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 21, ('r', 3): 18, ('r', 4): 16, ('r', 5): 14, ('r', 6): 12, ('r', 7): 10, ('r', 8): 8, ('r', 9): 6, ('r', 10): 4, ('r', 11): 2, ('r', 12): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 21, ('r', 3): 18, ('r', 4): 16, ('r', 5): 14, ('r', 6): 12, ('r', 7): 10, ('r', 8): 8, ('r', 9): 6, ('r', 10): 4, ('r', 11): 3, ('r', 12): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 21, ('r', 3): 19, ('r', 4): 16, ('r', 5): 14, ('r', 6): 12, ('r', 7): 10, ('r', 8): 8, ('r', 9): 6, ('r', 10): 4, ('r', 11): 3, ('r', 12): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 21, ('r', 3): 19, ('r', 4): 16, ('r', 5): 14, ('r', 6): 12, ('r', 7): 10, ('r', 8): 8, ('r', 9): 6, ('r', 10): 5, ('r', 11): 3, ('r', 12): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 21, ('r', 3): 19, ('r', 4): 17, ('r', 5): 14, ('r', 6): 12, ('r', 7): 10, ('r', 8): 8, ('r', 9): 6, ('r', 10): 5, ('r', 11): 3, ('r', 12): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 21, ('r', 3): 19, ('r', 4): 17, ('r', 5): 14, ('r', 6): 12, ('r', 7): 10, ('r', 8): 8, ('r', 9): 7, ('r', 10): 5, ('r', 11): 3, ('r', 12): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 21, ('r', 3): 19, ('r', 4): 17, ('r', 5): 15, ('r', 6): 12, ('r', 7): 10, ('r', 8): 8, ('r', 9): 7, ('r', 10): 5, ('r', 11): 3, ('r', 12): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 21, ('r', 3): 19, ('r', 4): 17, ('r', 5): 15, ('r', 6): 12, ('r', 7): 10, ('r', 8): 9, ('r', 9): 7, ('r', 10): 5, ('r', 11): 3, ('r', 12): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 21, ('r', 3): 19, ('r', 4): 17, ('r', 5): 15, ('r', 6): 13, ('r', 7): 10, ('r', 8): 9, ('r', 9): 7, ('r', 10): 5, ('r', 11): 3, ('r', 12): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 21, ('r', 3): 19, ('r', 4): 17, ('r', 5): 15, ('r', 6): 13, ('r', 7): 11, ('r', 8): 9, ('r', 9): 7, ('r', 10): 5, ('r', 11): 3, ('r', 12): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 21, ('r', 3): 19, ('r', 4): 17, ('r', 5): 15, ('r', 6): 13, ('r', 7): 12, ('r', 8): 9, ('r', 9): 7, ('r', 10): 5, ('r', 11): 3, ('r', 12): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 21, ('r', 3): 19, ('r', 4): 17, ('r', 5): 15, ('r', 6): 14, ('r', 7): 12, ('r', 8): 9, ('r', 9): 7, ('r', 10): 5, ('r', 11): 3, ('r', 12): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 21, ('r', 3): 19, ('r', 4): 17, ('r', 5): 15, ('r', 6): 14, ('r', 7): 12, ('r', 8): 10, ('r', 9): 7, ('r', 10): 5, ('r', 11): 3, ('r', 12): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 21, ('r', 3): 19, ('r', 4): 17, ('r', 5): 16, ('r', 6): 14, ('r', 7): 12, ('r', 8): 10, ('r', 9): 7, ('r', 10): 5, ('r', 11): 3, ('r', 12): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 21, ('r', 3): 19, ('r', 4): 17, ('r', 5): 16, ('r', 6): 14, ('r', 7): 12, ('r', 8): 10, ('r', 9): 8, ('r', 10): 5, ('r', 11): 3, ('r', 12): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 21, ('r', 3): 19, ('r', 4): 18, ('r', 5): 16, ('r', 6): 14, ('r', 7): 12, ('r', 8): 10, ('r', 9): 8, ('r', 10): 5, ('r', 11): 3, ('r', 12): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 21, ('r', 3): 19, ('r', 4): 18, ('r', 5): 16, ('r', 6): 14, ('r', 7): 12, ('r', 8): 10, ('r', 9): 8, ('r', 10): 6, ('r', 11): 3, ('r', 12): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 21, ('r', 3): 20, ('r', 4): 18, ('r', 5): 16, ('r', 6): 14, ('r', 7): 12, ('r', 8): 10, ('r', 9): 8, ('r', 10): 6, ('r', 11): 3, ('r', 12): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 21, ('r', 3): 20, ('r', 4): 18, ('r', 5): 16, ('r', 6): 14, ('r', 7): 12, ('r', 8): 10, ('r', 9): 8, ('r', 10): 6, ('r', 11): 4, ('r', 12): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 22, ('r', 3): 20, ('r', 4): 18, ('r', 5): 16, ('r', 6): 14, ('r', 7): 12, ('r', 8): 10, ('r', 9): 8, ('r', 10): 6, ('r', 11): 4, ('r', 12): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 32, ('r', 2): 22, ('r', 3): 20, ('r', 4): 18, ('r', 5): 16, ('r', 6): 14, ('r', 7): 12, ('r', 8): 10, ('r', 9): 8, ('r', 10): 6, ('r', 11): 4, ('r', 12): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 22, ('r', 3): 20, ('r', 4): 18, ('r', 5): 16, ('r', 6): 14, ('r', 7): 12, ('r', 8): 10, ('r', 9): 8, ('r', 10): 6, ('r', 11): 4, ('r', 12): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 22, ('r', 3): 20, ('r', 4): 18, ('r', 5): 16, ('r', 6): 14, ('r', 7): 12, ('r', 8): 10, ('r', 9): 8, ('r', 10): 6, ('r', 11): 4, ('r', 12): 2, ('r', 13): 1})
# function: r called once! used time: 0.005995988845825195
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 20, ('r', 4): 18, ('r', 5): 16, ('r', 6): 14, ('r', 7): 12, ('r', 8): 10, ('r', 9): 8, ('r', 10): 6, ('r', 11): 4, ('r', 12): 2, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 20, ('r', 4): 18, ('r', 5): 16, ('r', 6): 14, ('r', 7): 12, ('r', 8): 10, ('r', 9): 8, ('r', 10): 6, ('r', 11): 4, ('r', 12): 3, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 21, ('r', 4): 18, ('r', 5): 16, ('r', 6): 14, ('r', 7): 12, ('r', 8): 10, ('r', 9): 8, ('r', 10): 6, ('r', 11): 4, ('r', 12): 3, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 21, ('r', 4): 18, ('r', 5): 16, ('r', 6): 14, ('r', 7): 12, ('r', 8): 10, ('r', 9): 8, ('r', 10): 6, ('r', 11): 5, ('r', 12): 3, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 21, ('r', 4): 19, ('r', 5): 16, ('r', 6): 14, ('r', 7): 12, ('r', 8): 10, ('r', 9): 8, ('r', 10): 6, ('r', 11): 5, ('r', 12): 3, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 21, ('r', 4): 19, ('r', 5): 16, ('r', 6): 14, ('r', 7): 12, ('r', 8): 10, ('r', 9): 8, ('r', 10): 7, ('r', 11): 5, ('r', 12): 3, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 21, ('r', 4): 19, ('r', 5): 17, ('r', 6): 14, ('r', 7): 12, ('r', 8): 10, ('r', 9): 8, ('r', 10): 7, ('r', 11): 5, ('r', 12): 3, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 21, ('r', 4): 19, ('r', 5): 17, ('r', 6): 14, ('r', 7): 12, ('r', 8): 10, ('r', 9): 9, ('r', 10): 7, ('r', 11): 5, ('r', 12): 3, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 21, ('r', 4): 19, ('r', 5): 17, ('r', 6): 15, ('r', 7): 12, ('r', 8): 10, ('r', 9): 9, ('r', 10): 7, ('r', 11): 5, ('r', 12): 3, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 21, ('r', 4): 19, ('r', 5): 17, ('r', 6): 15, ('r', 7): 12, ('r', 8): 11, ('r', 9): 9, ('r', 10): 7, ('r', 11): 5, ('r', 12): 3, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 21, ('r', 4): 19, ('r', 5): 17, ('r', 6): 15, ('r', 7): 13, ('r', 8): 11, ('r', 9): 9, ('r', 10): 7, ('r', 11): 5, ('r', 12): 3, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 21, ('r', 4): 19, ('r', 5): 17, ('r', 6): 15, ('r', 7): 14, ('r', 8): 11, ('r', 9): 9, ('r', 10): 7, ('r', 11): 5, ('r', 12): 3, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 21, ('r', 4): 19, ('r', 5): 17, ('r', 6): 15, ('r', 7): 14, ('r', 8): 12, ('r', 9): 9, ('r', 10): 7, ('r', 11): 5, ('r', 12): 3, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 21, ('r', 4): 19, ('r', 5): 17, ('r', 6): 16, ('r', 7): 14, ('r', 8): 12, ('r', 9): 9, ('r', 10): 7, ('r', 11): 5, ('r', 12): 3, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 21, ('r', 4): 19, ('r', 5): 17, ('r', 6): 16, ('r', 7): 14, ('r', 8): 12, ('r', 9): 10, ('r', 10): 7, ('r', 11): 5, ('r', 12): 3, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 21, ('r', 4): 19, ('r', 5): 18, ('r', 6): 16, ('r', 7): 14, ('r', 8): 12, ('r', 9): 10, ('r', 10): 7, ('r', 11): 5, ('r', 12): 3, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 21, ('r', 4): 19, ('r', 5): 18, ('r', 6): 16, ('r', 7): 14, ('r', 8): 12, ('r', 9): 10, ('r', 10): 8, ('r', 11): 5, ('r', 12): 3, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 21, ('r', 4): 20, ('r', 5): 18, ('r', 6): 16, ('r', 7): 14, ('r', 8): 12, ('r', 9): 10, ('r', 10): 8, ('r', 11): 5, ('r', 12): 3, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 21, ('r', 4): 20, ('r', 5): 18, ('r', 6): 16, ('r', 7): 14, ('r', 8): 12, ('r', 9): 10, ('r', 10): 8, ('r', 11): 6, ('r', 12): 3, ('r', 13): 1})
# function: r called once! used time: 0.0010006427764892578
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 22, ('r', 4): 20, ('r', 5): 18, ('r', 6): 16, ('r', 7): 14, ('r', 8): 12, ('r', 9): 10, ('r', 10): 8, ('r', 11): 6, ('r', 12): 3, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 23, ('r', 3): 22, ('r', 4): 20, ('r', 5): 18, ('r', 6): 16, ('r', 7): 14, ('r', 8): 12, ('r', 9): 10, ('r', 10): 8, ('r', 11): 6, ('r', 12): 4, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 24, ('r', 3): 22, ('r', 4): 20, ('r', 5): 18, ('r', 6): 16, ('r', 7): 14, ('r', 8): 12, ('r', 9): 10, ('r', 10): 8, ('r', 11): 6, ('r', 12): 4, ('r', 13): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 33, ('r', 2): 24, ('r', 3): 22, ('r', 4): 20, ('r', 5): 18, ('r', 6): 16, ('r', 7): 14, ('r', 8): 12, ('r', 9): 10, ('r', 10): 8, ('r', 11): 6, ('r', 12): 4, ('r', 13): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 24, ('r', 3): 22, ('r', 4): 20, ('r', 5): 18, ('r', 6): 16, ('r', 7): 14, ('r', 8): 12, ('r', 9): 10, ('r', 10): 8, ('r', 11): 6, ('r', 12): 4, ('r', 13): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 24, ('r', 3): 22, ('r', 4): 20, ('r', 5): 18, ('r', 6): 16, ('r', 7): 14, ('r', 8): 12, ('r', 9): 10, ('r', 10): 8, ('r', 11): 6, ('r', 12): 4, ('r', 13): 2, ('r', 14): 1})
# function: r called once! used time: 0.006996631622314453
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 22, ('r', 4): 20, ('r', 5): 18, ('r', 6): 16, ('r', 7): 14, ('r', 8): 12, ('r', 9): 10, ('r', 10): 8, ('r', 11): 6, ('r', 12): 4, ('r', 13): 2, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 22, ('r', 4): 20, ('r', 5): 18, ('r', 6): 16, ('r', 7): 14, ('r', 8): 12, ('r', 9): 10, ('r', 10): 8, ('r', 11): 6, ('r', 12): 4, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 23, ('r', 4): 20, ('r', 5): 18, ('r', 6): 16, ('r', 7): 14, ('r', 8): 12, ('r', 9): 10, ('r', 10): 8, ('r', 11): 6, ('r', 12): 4, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 23, ('r', 4): 20, ('r', 5): 18, ('r', 6): 16, ('r', 7): 14, ('r', 8): 12, ('r', 9): 10, ('r', 10): 8, ('r', 11): 6, ('r', 12): 5, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 23, ('r', 4): 21, ('r', 5): 18, ('r', 6): 16, ('r', 7): 14, ('r', 8): 12, ('r', 9): 10, ('r', 10): 8, ('r', 11): 6, ('r', 12): 5, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 23, ('r', 4): 21, ('r', 5): 18, ('r', 6): 16, ('r', 7): 14, ('r', 8): 12, ('r', 9): 10, ('r', 10): 8, ('r', 11): 7, ('r', 12): 5, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 23, ('r', 4): 21, ('r', 5): 19, ('r', 6): 16, ('r', 7): 14, ('r', 8): 12, ('r', 9): 10, ('r', 10): 8, ('r', 11): 7, ('r', 12): 5, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 23, ('r', 4): 21, ('r', 5): 19, ('r', 6): 16, ('r', 7): 14, ('r', 8): 12, ('r', 9): 10, ('r', 10): 9, ('r', 11): 7, ('r', 12): 5, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 23, ('r', 4): 21, ('r', 5): 19, ('r', 6): 17, ('r', 7): 14, ('r', 8): 12, ('r', 9): 10, ('r', 10): 9, ('r', 11): 7, ('r', 12): 5, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 23, ('r', 4): 21, ('r', 5): 19, ('r', 6): 17, ('r', 7): 14, ('r', 8): 12, ('r', 9): 11, ('r', 10): 9, ('r', 11): 7, ('r', 12): 5, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 23, ('r', 4): 21, ('r', 5): 19, ('r', 6): 17, ('r', 7): 15, ('r', 8): 12, ('r', 9): 11, ('r', 10): 9, ('r', 11): 7, ('r', 12): 5, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 23, ('r', 4): 21, ('r', 5): 19, ('r', 6): 17, ('r', 7): 15, ('r', 8): 13, ('r', 9): 11, ('r', 10): 9, ('r', 11): 7, ('r', 12): 5, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 23, ('r', 4): 21, ('r', 5): 19, ('r', 6): 17, ('r', 7): 15, ('r', 8): 14, ('r', 9): 11, ('r', 10): 9, ('r', 11): 7, ('r', 12): 5, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 23, ('r', 4): 21, ('r', 5): 19, ('r', 6): 17, ('r', 7): 16, ('r', 8): 14, ('r', 9): 11, ('r', 10): 9, ('r', 11): 7, ('r', 12): 5, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 23, ('r', 4): 21, ('r', 5): 19, ('r', 6): 17, ('r', 7): 16, ('r', 8): 14, ('r', 9): 12, ('r', 10): 9, ('r', 11): 7, ('r', 12): 5, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 23, ('r', 4): 21, ('r', 5): 19, ('r', 6): 18, ('r', 7): 16, ('r', 8): 14, ('r', 9): 12, ('r', 10): 9, ('r', 11): 7, ('r', 12): 5, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 23, ('r', 4): 21, ('r', 5): 19, ('r', 6): 18, ('r', 7): 16, ('r', 8): 14, ('r', 9): 12, ('r', 10): 10, ('r', 11): 7, ('r', 12): 5, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0010008811950683594
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 23, ('r', 4): 21, ('r', 5): 20, ('r', 6): 18, ('r', 7): 16, ('r', 8): 14, ('r', 9): 12, ('r', 10): 10, ('r', 11): 7, ('r', 12): 5, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 23, ('r', 4): 21, ('r', 5): 20, ('r', 6): 18, ('r', 7): 16, ('r', 8): 14, ('r', 9): 12, ('r', 10): 10, ('r', 11): 8, ('r', 12): 5, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 23, ('r', 4): 22, ('r', 5): 20, ('r', 6): 18, ('r', 7): 16, ('r', 8): 14, ('r', 9): 12, ('r', 10): 10, ('r', 11): 8, ('r', 12): 5, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 23, ('r', 4): 22, ('r', 5): 20, ('r', 6): 18, ('r', 7): 16, ('r', 8): 14, ('r', 9): 12, ('r', 10): 10, ('r', 11): 8, ('r', 12): 6, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 24, ('r', 4): 22, ('r', 5): 20, ('r', 6): 18, ('r', 7): 16, ('r', 8): 14, ('r', 9): 12, ('r', 10): 10, ('r', 11): 8, ('r', 12): 6, ('r', 13): 3, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 25, ('r', 3): 24, ('r', 4): 22, ('r', 5): 20, ('r', 6): 18, ('r', 7): 16, ('r', 8): 14, ('r', 9): 12, ('r', 10): 10, ('r', 11): 8, ('r', 12): 6, ('r', 13): 4, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 26, ('r', 3): 24, ('r', 4): 22, ('r', 5): 20, ('r', 6): 18, ('r', 7): 16, ('r', 8): 14, ('r', 9): 12, ('r', 10): 10, ('r', 11): 8, ('r', 12): 6, ('r', 13): 4, ('r', 14): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 34, ('r', 2): 26, ('r', 3): 24, ('r', 4): 22, ('r', 5): 20, ('r', 6): 18, ('r', 7): 16, ('r', 8): 14, ('r', 9): 12, ('r', 10): 10, ('r', 11): 8, ('r', 12): 6, ('r', 13): 4, ('r', 14): 2})
# function: r called once! used time: 0.0
# ...
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 36, ('r', 4): 34, ('r', 5): 32, ('r', 6): 30, ('r', 7): 28, ('r', 8): 26, ('r', 9): 24, ('r', 10): 22, ('r', 11): 20, ('r', 12): 18, ('r', 13): 16, ('r', 14): 14, ('r', 15): 12, ('r', 16): 10, ('r', 17): 8, ('r', 18): 6, ('r', 19): 4, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 34, ('r', 5): 32, ('r', 6): 30, ('r', 7): 28, ('r', 8): 26, ('r', 9): 24, ('r', 10): 22, ('r', 11): 20, ('r', 12): 18, ('r', 13): 16, ('r', 14): 14, ('r', 15): 12, ('r', 16): 10, ('r', 17): 8, ('r', 18): 6, ('r', 19): 4, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 34, ('r', 5): 32, ('r', 6): 30, ('r', 7): 28, ('r', 8): 26, ('r', 9): 24, ('r', 10): 22, ('r', 11): 20, ('r', 12): 18, ('r', 13): 16, ('r', 14): 14, ('r', 15): 12, ('r', 16): 10, ('r', 17): 8, ('r', 18): 6, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 32, ('r', 6): 30, ('r', 7): 28, ('r', 8): 26, ('r', 9): 24, ('r', 10): 22, ('r', 11): 20, ('r', 12): 18, ('r', 13): 16, ('r', 14): 14, ('r', 15): 12, ('r', 16): 10, ('r', 17): 8, ('r', 18): 6, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 32, ('r', 6): 30, ('r', 7): 28, ('r', 8): 26, ('r', 9): 24, ('r', 10): 22, ('r', 11): 20, ('r', 12): 18, ('r', 13): 16, ('r', 14): 14, ('r', 15): 12, ('r', 16): 10, ('r', 17): 8, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 30, ('r', 7): 28, ('r', 8): 26, ('r', 9): 24, ('r', 10): 22, ('r', 11): 20, ('r', 12): 18, ('r', 13): 16, ('r', 14): 14, ('r', 15): 12, ('r', 16): 10, ('r', 17): 8, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 30, ('r', 7): 28, ('r', 8): 26, ('r', 9): 24, ('r', 10): 22, ('r', 11): 20, ('r', 12): 18, ('r', 13): 16, ('r', 14): 14, ('r', 15): 12, ('r', 16): 10, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 28, ('r', 8): 26, ('r', 9): 24, ('r', 10): 22, ('r', 11): 20, ('r', 12): 18, ('r', 13): 16, ('r', 14): 14, ('r', 15): 12, ('r', 16): 10, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 28, ('r', 8): 26, ('r', 9): 24, ('r', 10): 22, ('r', 11): 20, ('r', 12): 18, ('r', 13): 16, ('r', 14): 14, ('r', 15): 12, ('r', 16): 11, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 29, ('r', 8): 26, ('r', 9): 24, ('r', 10): 22, ('r', 11): 20, ('r', 12): 18, ('r', 13): 16, ('r', 14): 14, ('r', 15): 12, ('r', 16): 11, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 29, ('r', 8): 26, ('r', 9): 24, ('r', 10): 22, ('r', 11): 20, ('r', 12): 18, ('r', 13): 16, ('r', 14): 14, ('r', 15): 13, ('r', 16): 11, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 29, ('r', 8): 27, ('r', 9): 24, ('r', 10): 22, ('r', 11): 20, ('r', 12): 18, ('r', 13): 16, ('r', 14): 14, ('r', 15): 13, ('r', 16): 11, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 29, ('r', 8): 27, ('r', 9): 24, ('r', 10): 22, ('r', 11): 20, ('r', 12): 18, ('r', 13): 16, ('r', 14): 15, ('r', 15): 13, ('r', 16): 11, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 29, ('r', 8): 27, ('r', 9): 25, ('r', 10): 22, ('r', 11): 20, ('r', 12): 18, ('r', 13): 16, ('r', 14): 15, ('r', 15): 13, ('r', 16): 11, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 29, ('r', 8): 27, ('r', 9): 25, ('r', 10): 22, ('r', 11): 20, ('r', 12): 18, ('r', 13): 17, ('r', 14): 15, ('r', 15): 13, ('r', 16): 11, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 29, ('r', 8): 27, ('r', 9): 25, ('r', 10): 23, ('r', 11): 20, ('r', 12): 18, ('r', 13): 17, ('r', 14): 15, ('r', 15): 13, ('r', 16): 11, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 29, ('r', 8): 27, ('r', 9): 25, ('r', 10): 23, ('r', 11): 20, ('r', 12): 19, ('r', 13): 17, ('r', 14): 15, ('r', 15): 13, ('r', 16): 11, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 29, ('r', 8): 27, ('r', 9): 25, ('r', 10): 23, ('r', 11): 21, ('r', 12): 19, ('r', 13): 17, ('r', 14): 15, ('r', 15): 13, ('r', 16): 11, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 29, ('r', 8): 27, ('r', 9): 25, ('r', 10): 23, ('r', 11): 22, ('r', 12): 19, ('r', 13): 17, ('r', 14): 15, ('r', 15): 13, ('r', 16): 11, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 29, ('r', 8): 27, ('r', 9): 25, ('r', 10): 23, ('r', 11): 22, ('r', 12): 20, ('r', 13): 17, ('r', 14): 15, ('r', 15): 13, ('r', 16): 11, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 29, ('r', 8): 27, ('r', 9): 25, ('r', 10): 24, ('r', 11): 22, ('r', 12): 20, ('r', 13): 17, ('r', 14): 15, ('r', 15): 13, ('r', 16): 11, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 29, ('r', 8): 27, ('r', 9): 25, ('r', 10): 24, ('r', 11): 22, ('r', 12): 20, ('r', 13): 18, ('r', 14): 15, ('r', 15): 13, ('r', 16): 11, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 29, ('r', 8): 27, ('r', 9): 26, ('r', 10): 24, ('r', 11): 22, ('r', 12): 20, ('r', 13): 18, ('r', 14): 15, ('r', 15): 13, ('r', 16): 11, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0010004043579101562
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 29, ('r', 8): 27, ('r', 9): 26, ('r', 10): 24, ('r', 11): 22, ('r', 12): 20, ('r', 13): 18, ('r', 14): 16, ('r', 15): 13, ('r', 16): 11, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 29, ('r', 8): 28, ('r', 9): 26, ('r', 10): 24, ('r', 11): 22, ('r', 12): 20, ('r', 13): 18, ('r', 14): 16, ('r', 15): 13, ('r', 16): 11, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 29, ('r', 8): 28, ('r', 9): 26, ('r', 10): 24, ('r', 11): 22, ('r', 12): 20, ('r', 13): 18, ('r', 14): 16, ('r', 15): 14, ('r', 16): 11, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 30, ('r', 8): 28, ('r', 9): 26, ('r', 10): 24, ('r', 11): 22, ('r', 12): 20, ('r', 13): 18, ('r', 14): 16, ('r', 15): 14, ('r', 16): 11, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 31, ('r', 7): 30, ('r', 8): 28, ('r', 9): 26, ('r', 10): 24, ('r', 11): 22, ('r', 12): 20, ('r', 13): 18, ('r', 14): 16, ('r', 15): 14, ('r', 16): 12, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 32, ('r', 7): 30, ('r', 8): 28, ('r', 9): 26, ('r', 10): 24, ('r', 11): 22, ('r', 12): 20, ('r', 13): 18, ('r', 14): 16, ('r', 15): 14, ('r', 16): 12, ('r', 17): 9, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 33, ('r', 6): 32, ('r', 7): 30, ('r', 8): 28, ('r', 9): 26, ('r', 10): 24, ('r', 11): 22, ('r', 12): 20, ('r', 13): 18, ('r', 14): 16, ('r', 15): 14, ('r', 16): 12, ('r', 17): 10, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 34, ('r', 6): 32, ('r', 7): 30, ('r', 8): 28, ('r', 9): 26, ('r', 10): 24, ('r', 11): 22, ('r', 12): 20, ('r', 13): 18, ('r', 14): 16, ('r', 15): 14, ('r', 16): 12, ('r', 17): 10, ('r', 18): 7, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 35, ('r', 5): 34, ('r', 6): 32, ('r', 7): 30, ('r', 8): 28, ('r', 9): 26, ('r', 10): 24, ('r', 11): 22, ('r', 12): 20, ('r', 13): 18, ('r', 14): 16, ('r', 15): 14, ('r', 16): 12, ('r', 17): 10, ('r', 18): 8, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 36, ('r', 5): 34, ('r', 6): 32, ('r', 7): 30, ('r', 8): 28, ('r', 9): 26, ('r', 10): 24, ('r', 11): 22, ('r', 12): 20, ('r', 13): 18, ('r', 14): 16, ('r', 15): 14, ('r', 16): 12, ('r', 17): 10, ('r', 18): 8, ('r', 19): 5, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 37, ('r', 4): 36, ('r', 5): 34, ('r', 6): 32, ('r', 7): 30, ('r', 8): 28, ('r', 9): 26, ('r', 10): 24, ('r', 11): 22, ('r', 12): 20, ('r', 13): 18, ('r', 14): 16, ('r', 15): 14, ('r', 16): 12, ('r', 17): 10, ('r', 18): 8, ('r', 19): 6, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 38, ('r', 4): 36, ('r', 5): 34, ('r', 6): 32, ('r', 7): 30, ('r', 8): 28, ('r', 9): 26, ('r', 10): 24, ('r', 11): 22, ('r', 12): 20, ('r', 13): 18, ('r', 14): 16, ('r', 15): 14, ('r', 16): 12, ('r', 17): 10, ('r', 18): 8, ('r', 19): 6, ('r', 20): 3, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 39, ('r', 3): 38, ('r', 4): 36, ('r', 5): 34, ('r', 6): 32, ('r', 7): 30, ('r', 8): 28, ('r', 9): 26, ('r', 10): 24, ('r', 11): 22, ('r', 12): 20, ('r', 13): 18, ('r', 14): 16, ('r', 15): 14, ('r', 16): 12, ('r', 17): 10, ('r', 18): 8, ('r', 19): 6, ('r', 20): 4, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 40, ('r', 3): 38, ('r', 4): 36, ('r', 5): 34, ('r', 6): 32, ('r', 7): 30, ('r', 8): 28, ('r', 9): 26, ('r', 10): 24, ('r', 11): 22, ('r', 12): 20, ('r', 13): 18, ('r', 14): 16, ('r', 15): 14, ('r', 16): 12, ('r', 17): 10, ('r', 18): 8, ('r', 19): 6, ('r', 20): 4, ('r', 21): 1})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 41, ('r', 2): 40, ('r', 3): 38, ('r', 4): 36, ('r', 5): 34, ('r', 6): 32, ('r', 7): 30, ('r', 8): 28, ('r', 9): 26, ('r', 10): 24, ('r', 11): 22, ('r', 12): 20, ('r', 13): 18, ('r', 14): 16, ('r', 15): 14, ('r', 16): 12, ('r', 17): 10, ('r', 18): 8, ('r', 19): 6, ('r', 20): 4, ('r', 21): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 42, ('r', 2): 40, ('r', 3): 38, ('r', 4): 36, ('r', 5): 34, ('r', 6): 32, ('r', 7): 30, ('r', 8): 28, ('r', 9): 26, ('r', 10): 24, ('r', 11): 22, ('r', 12): 20, ('r', 13): 18, ('r', 14): 16, ('r', 15): 14, ('r', 16): 12, ('r', 17): 10, ('r', 18): 8, ('r', 19): 6, ('r', 20): 4, ('r', 21): 2})
# function: r called once! used time: 0.0
# this is defaultdict(<class 'int'>, {('add_ten', 20): 1, ('r', 1): 42, ('r', 2): 40, ('r', 3): 38, ('r', 4): 36, ('r', 5): 34, ('r', 6): 32, ('r', 7): 30, ('r', 8): 28, ('r', 9): 26, ('r', 10): 24, ('r', 11): 22, ('r', 12): 20, ('r', 13): 18, ('r', 14): 16, ('r', 15): 14, ('r', 16): 12, ('r', 17): 10, ('r', 18): 8, ('r', 19): 6, ('r', 20): 4, ('r', 21): 2, ('r', 22): 1})
# function: r called once! used time: 0.034020185470581055
# 65

# %%
solution
# Out:
# {1: (1, 0),
#  2: (2, 0),
#  3: (3, 0),
#  4: (2, 2),
#  5: (3, 2),
#  6: (6, 0),
#  7: (6, 1),
#  8: (6, 2),
#  9: (6, 3),
#  10: (10, 0),
#  11: (11, 0),
#  12: (10, 2),
#  13: (10, 3),
#  14: (12, 2),
#  15: (13, 2),
#  16: (10, 6),
#  17: (16, 1),
#  18: (16, 2),
#  19: (16, 3),
#  20: (10, 10),
#  21: (20, 1),
#  22: (20, 2)}

# %%
def parse_solution(n):
    left_split, right_split = solution[n]
    
    if right_split == 0: return [left_split]
    
    return parse_solution(left_split) + parse_solution(right_split)

# %%
r(231)
# Out:
# 691

# %%
parse_solution(231)
# Out:
# [10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  10,
#  1]

# %%
r(20)
# Out:
# 60

# %%
r(245)
# Out:
# 733

# %%
r
# Out:
# <function __main__.r(n)>

# %%
called_time_with_arg
# Out:
# defaultdict(int,
#             {('r', 1): 488,
#              ('r', 2): 486,
#              ('r', 3): 484,
#              ('r', 4): 482,
#              ('r', 5): 480,
#              ('r', 6): 478,
#              ('r', 7): 476,
#              ('r', 8): 474,
#              ('r', 9): 472,
#              ('r', 10): 470,
#              ('r', 11): 468,
#              ('r', 12): 466,
#              ('r', 13): 464,
#              ('r', 14): 462,
#              ('r', 15): 460,
#              ('r', 16): 458,
#              ('r', 17): 456,
#              ('r', 18): 454,
#              ('r', 19): 452,
#              ('r', 20): 451,
#              ('r', 21): 448,
#              ('r', 22): 447,
#              ('r', 23): 444,
#              ('r', 24): 442,
#              ('r', 25): 440,
#              ('r', 26): 438,
#              ('r', 27): 436,
#              ('r', 28): 434,
#              ('r', 29): 432,
#              ('r', 30): 430,
#              ('r', 31): 428,
#              ('r', 32): 426,
#              ('r', 33): 424,
#              ('r', 34): 422,
#              ('r', 35): 420,
#              ('r', 36): 418,
#              ('r', 37): 416,
#              ('r', 38): 414,
#              ('r', 39): 412,
#              ('r', 40): 410,
#              ('r', 41): 408,
#              ('r', 42): 406,
#              ('r', 43): 404,
#              ('r', 44): 402,
#              ('r', 45): 400,
#              ('r', 46): 398,
#              ('r', 47): 396,
#              ('r', 48): 394,
#              ('r', 49): 392,
#              ('r', 50): 390,
#              ('r', 51): 388,
#              ('r', 52): 386,
#              ('r', 53): 384,
#              ('r', 54): 382,
#              ('r', 55): 380,
#              ('r', 56): 378,
#              ('r', 57): 376,
#              ('r', 58): 374,
#              ('r', 59): 372,
#              ('r', 60): 370,
#              ('r', 61): 368,
#              ('r', 62): 366,
#              ('r', 63): 364,
#              ('r', 64): 362,
#              ('r', 65): 360,
#              ('r', 66): 358,
#              ('r', 67): 356,
#              ('r', 68): 354,
#              ('r', 69): 352,
#              ('r', 70): 350,
#              ('r', 71): 348,
#              ('r', 72): 346,
#              ('r', 73): 344,
#              ('r', 74): 342,
#              ('r', 75): 340,
#              ('r', 76): 338,
#              ('r', 77): 336,
#              ('r', 78): 334,
#              ('r', 79): 332,
#              ('r', 80): 330,
#              ('r', 81): 328,
#              ('r', 82): 326,
#              ('r', 83): 324,
#              ('r', 84): 322,
#              ('r', 85): 320,
#              ('r', 86): 318,
#              ('r', 87): 316,
#              ('r', 88): 314,
#              ('r', 89): 312,
#              ('r', 90): 310,
#              ('r', 91): 308,
#              ('r', 92): 306,
#              ('r', 93): 304,
#              ('r', 94): 302,
#              ('r', 95): 300,
#              ('r', 96): 298,
#              ('r', 97): 296,
#              ('r', 98): 294,
#              ('r', 99): 292,
#              ('r', 100): 290,
#              ('r', 101): 288,
#              ('r', 102): 286,
#              ('r', 103): 284,
#              ('r', 104): 282,
#              ('r', 105): 280,
#              ('r', 106): 278,
#              ('r', 107): 276,
#              ('r', 108): 274,
#              ('r', 109): 272,
#              ('r', 110): 270,
#              ('r', 111): 268,
#              ('r', 112): 266,
#              ('r', 113): 264,
#              ('r', 114): 262,
#              ('r', 115): 260,
#              ('r', 116): 258,
#              ('r', 117): 256,
#              ('r', 118): 254,
#              ('r', 119): 252,
#              ('r', 120): 250,
#              ('r', 121): 248,
#              ('r', 122): 246,
#              ('r', 123): 244,
#              ('r', 124): 242,
#              ('r', 125): 240,
#              ('r', 126): 238,
#              ('r', 127): 236,
#              ('r', 128): 234,
#              ('r', 129): 232,
#              ('r', 130): 230,
#              ('r', 131): 228,
#              ('r', 132): 226,
#              ('r', 133): 224,
#              ('r', 134): 222,
#              ('r', 135): 220,
#              ('r', 136): 218,
#              ('r', 137): 216,
#              ('r', 138): 214,
#              ('r', 139): 212,
#              ('r', 140): 210,
#              ('r', 141): 208,
#              ('r', 142): 206,
#              ('r', 143): 204,
#              ('r', 144): 202,
#              ('r', 145): 200,
#              ('r', 146): 198,
#              ('r', 147): 196,
#              ('r', 148): 194,
#              ('r', 149): 192,
#              ('r', 150): 190,
#              ('r', 151): 188,
#              ('r', 152): 186,
#              ('r', 153): 184,
#              ('r', 154): 182,
#              ('r', 155): 180,
#              ('r', 156): 178,
#              ('r', 157): 176,
#              ('r', 158): 174,
#              ('r', 159): 172,
#              ('r', 160): 170,
#              ('r', 161): 168,
#              ('r', 162): 166,
#              ('r', 163): 164,
#              ('r', 164): 162,
#              ('r', 165): 160,
#              ('r', 166): 158,
#              ('r', 167): 156,
#              ('r', 168): 154,
#              ('r', 169): 152,
#              ('r', 170): 150,
#              ('r', 171): 148,
#              ('r', 172): 146,
#              ('r', 173): 144,
#              ('r', 174): 142,
#              ('r', 175): 140,
#              ('r', 176): 138,
#              ('r', 177): 136,
#              ('r', 178): 134,
#              ('r', 179): 132,
#              ('r', 180): 130,
#              ('r', 181): 128,
#              ('r', 182): 126,
#              ('r', 183): 124,
#              ('r', 184): 122,
#              ('r', 185): 120,
#              ('r', 186): 118,
#              ('r', 187): 116,
#              ('r', 188): 114,
#              ('r', 189): 112,
#              ('r', 190): 110,
#              ('r', 191): 108,
#              ('r', 192): 106,
#              ('r', 193): 104,
#              ('r', 194): 102,
#              ('r', 195): 100,
#              ('r', 196): 98,
#              ('r', 197): 96,
#              ('r', 198): 94,
#              ('r', 199): 92,
#              ('r', 200): 90,
#              ('r', 201): 88,
#              ('r', 202): 86,
#              ('r', 203): 84,
#              ('r', 204): 82,
#              ('r', 205): 80,
#              ('r', 206): 78,
#              ('r', 207): 76,
#              ('r', 208): 74,
#              ('r', 209): 72,
#              ('r', 210): 70,
#              ('r', 211): 68,
#              ('r', 212): 66,
#              ('r', 213): 64,
#              ('r', 214): 62,
#              ('r', 215): 60,
#              ('r', 216): 58,
#              ('r', 217): 56,
#              ('r', 218): 54,
#              ('r', 219): 52,
#              ('r', 220): 50,
#              ('r', 221): 48,
#              ('r', 222): 46,
#              ('r', 223): 44,
#              ('r', 224): 42,
#              ('r', 225): 40,
#              ('r', 226): 38,
#              ('r', 227): 36,
#              ('r', 228): 34,
#              ('r', 229): 32,
#              ('r', 230): 30,
#              ('r', 231): 29,
#              ('r', 232): 26,
#              ('r', 233): 24,
#              ('r', 234): 22,
#              ('r', 235): 20,
#              ('r', 236): 18,
#              ('r', 237): 16,
#              ('r', 238): 14,
#              ('r', 239): 12,
#              ('r', 240): 10,
#              ('r', 241): 8,
#              ('r', 242): 6,
#              ('r', 243): 4,
#              ('r', 244): 2,
#              ('r', 245): 1})

# %%
from collections import Counter

# %%
Counter(called_time_with_arg).most_common()
# Out:
# [(('r', 1), 488),
#  (('r', 2), 486),
#  (('r', 3), 484),
#  (('r', 4), 482),
#  (('r', 5), 480),
#  (('r', 6), 478),
#  (('r', 7), 476),
#  (('r', 8), 474),
#  (('r', 9), 472),
#  (('r', 10), 470),
#  (('r', 11), 468),
#  (('r', 12), 466),
#  (('r', 13), 464),
#  (('r', 14), 462),
#  (('r', 15), 460),
#  (('r', 16), 458),
#  (('r', 17), 456),
#  (('r', 18), 454),
#  (('r', 19), 452),
#  (('r', 20), 451),
#  (('r', 21), 448),
#  (('r', 22), 447),
#  (('r', 23), 444),
#  (('r', 24), 442),
#  (('r', 25), 440),
#  (('r', 26), 438),
#  (('r', 27), 436),
#  (('r', 28), 434),
#  (('r', 29), 432),
#  (('r', 30), 430),
#  (('r', 31), 428),
#  (('r', 32), 426),
#  (('r', 33), 424),
#  (('r', 34), 422),
#  (('r', 35), 420),
#  (('r', 36), 418),
#  (('r', 37), 416),
#  (('r', 38), 414),
#  (('r', 39), 412),
#  (('r', 40), 410),
#  (('r', 41), 408),
#  (('r', 42), 406),
#  (('r', 43), 404),
#  (('r', 44), 402),
#  (('r', 45), 400),
#  (('r', 46), 398),
#  (('r', 47), 396),
#  (('r', 48), 394),
#  (('r', 49), 392),
#  (('r', 50), 390),
#  (('r', 51), 388),
#  (('r', 52), 386),
#  (('r', 53), 384),
#  (('r', 54), 382),
#  (('r', 55), 380),
#  (('r', 56), 378),
#  (('r', 57), 376),
#  (('r', 58), 374),
#  (('r', 59), 372),
#  (('r', 60), 370),
#  (('r', 61), 368),
#  (('r', 62), 366),
#  (('r', 63), 364),
#  (('r', 64), 362),
#  (('r', 65), 360),
#  (('r', 66), 358),
#  (('r', 67), 356),
#  (('r', 68), 354),
#  (('r', 69), 352),
#  (('r', 70), 350),
#  (('r', 71), 348),
#  (('r', 72), 346),
#  (('r', 73), 344),
#  (('r', 74), 342),
#  (('r', 75), 340),
#  (('r', 76), 338),
#  (('r', 77), 336),
#  (('r', 78), 334),
#  (('r', 79), 332),
#  (('r', 80), 330),
#  (('r', 81), 328),
#  (('r', 82), 326),
#  (('r', 83), 324),
#  (('r', 84), 322),
#  (('r', 85), 320),
#  (('r', 86), 318),
#  (('r', 87), 316),
#  (('r', 88), 314),
#  (('r', 89), 312),
#  (('r', 90), 310),
#  (('r', 91), 308),
#  (('r', 92), 306),
#  (('r', 93), 304),
#  (('r', 94), 302),
#  (('r', 95), 300),
#  (('r', 96), 298),
#  (('r', 97), 296),
#  (('r', 98), 294),
#  (('r', 99), 292),
#  (('r', 100), 290),
#  (('r', 101), 288),
#  (('r', 102), 286),
#  (('r', 103), 284),
#  (('r', 104), 282),
#  (('r', 105), 280),
#  (('r', 106), 278),
#  (('r', 107), 276),
#  (('r', 108), 274),
#  (('r', 109), 272),
#  (('r', 110), 270),
#  (('r', 111), 268),
#  (('r', 112), 266),
#  (('r', 113), 264),
#  (('r', 114), 262),
#  (('r', 115), 260),
#  (('r', 116), 258),
#  (('r', 117), 256),
#  (('r', 118), 254),
#  (('r', 119), 252),
#  (('r', 120), 250),
#  (('r', 121), 248),
#  (('r', 122), 246),
#  (('r', 123), 244),
#  (('r', 124), 242),
#  (('r', 125), 240),
#  (('r', 126), 238),
#  (('r', 127), 236),
#  (('r', 128), 234),
#  (('r', 129), 232),
#  (('r', 130), 230),
#  (('r', 131), 228),
#  (('r', 132), 226),
#  (('r', 133), 224),
#  (('r', 134), 222),
#  (('r', 135), 220),
#  (('r', 136), 218),
#  (('r', 137), 216),
#  (('r', 138), 214),
#  (('r', 139), 212),
#  (('r', 140), 210),
#  (('r', 141), 208),
#  (('r', 142), 206),
#  (('r', 143), 204),
#  (('r', 144), 202),
#  (('r', 145), 200),
#  (('r', 146), 198),
#  (('r', 147), 196),
#  (('r', 148), 194),
#  (('r', 149), 192),
#  (('r', 150), 190),
#  (('r', 151), 188),
#  (('r', 152), 186),
#  (('r', 153), 184),
#  (('r', 154), 182),
#  (('r', 155), 180),
#  (('r', 156), 178),
#  (('r', 157), 176),
#  (('r', 158), 174),
#  (('r', 159), 172),
#  (('r', 160), 170),
#  (('r', 161), 168),
#  (('r', 162), 166),
#  (('r', 163), 164),
#  (('r', 164), 162),
#  (('r', 165), 160),
#  (('r', 166), 158),
#  (('r', 167), 156),
#  (('r', 168), 154),
#  (('r', 169), 152),
#  (('r', 170), 150),
#  (('r', 171), 148),
#  (('r', 172), 146),
#  (('r', 173), 144),
#  (('r', 174), 142),
#  (('r', 175), 140),
#  (('r', 176), 138),
#  (('r', 177), 136),
#  (('r', 178), 134),
#  (('r', 179), 132),
#  (('r', 180), 130),
#  (('r', 181), 128),
#  (('r', 182), 126),
#  (('r', 183), 124),
#  (('r', 184), 122),
#  (('r', 185), 120),
#  (('r', 186), 118),
#  (('r', 187), 116),
#  (('r', 188), 114),
#  (('r', 189), 112),
#  (('r', 190), 110),
#  (('r', 191), 108),
#  (('r', 192), 106),
#  (('r', 193), 104),
#  (('r', 194), 102),
#  (('r', 195), 100),
#  (('r', 196), 98),
#  (('r', 197), 96),
#  (('r', 198), 94),
#  (('r', 199), 92),
#  (('r', 200), 90),
#  (('r', 201), 88),
#  (('r', 202), 86),
#  (('r', 203), 84),
#  (('r', 204), 82),
#  (('r', 205), 80),
#  (('r', 206), 78),
#  (('r', 207), 76),
#  (('r', 208), 74),
#  (('r', 209), 72),
#  (('r', 210), 70),
#  (('r', 211), 68),
#  (('r', 212), 66),
#  (('r', 213), 64),
#  (('r', 214), 62),
#  (('r', 215), 60),
#  (('r', 216), 58),
#  (('r', 217), 56),
#  (('r', 218), 54),
#  (('r', 219), 52),
#  (('r', 220), 50),
#  (('r', 221), 48),
#  (('r', 222), 46),
#  (('r', 223), 44),
#  (('r', 224), 42),
#  (('r', 225), 40),
#  (('r', 226), 38),
#  (('r', 227), 36),
#  (('r', 228), 34),
#  (('r', 229), 32),
#  (('r', 230), 30),
#  (('r', 231), 29),
#  (('r', 232), 26),
#  (('r', 233), 24),
#  (('r', 234), 22),
#  (('r', 235), 20),
#  (('r', 236), 18),
#  (('r', 237), 16),
#  (('r', 238), 14),
#  (('r', 239), 12),
#  (('r', 240), 10),
#  (('r', 241), 8),
#  (('r', 242), 6),
#  (('r', 243), 4),
#  (('r', 244), 2),
#  (('r', 245), 1)]

# %%
r(15)
# Out:
# 43
